# %%
import pandas as pd
arm_data= pd.read_csv("arm_data.csv",header = None)

# %%
arm_data
# Out:
#               0             1        2          3          4          5   \
# 0            the     spongebob    movie     sponge        out         of
# 1      entourage          doug    ellin     adrian    grenier      kevin
# 2          split             m    night  shyamalan      james     mcavoy
# 3      scoobydoo  wrestlemania  mystery    brandon     vietti   seunggoo
# 4      scoobydoo         music       of        the    vampire      david
# ...          ...           ...      ...        ...        ...        ...
# 16577      stree          amar  kaushik     ashish     chhipa  rajkummar
# 16578      creep           NaN  patrick      brice      karan       soni
# 16579    hacksaw         ridge      mel     gibson     andrew   garfield
# 16580      ready        player      one     steven  spielberg        tye
# 16581        the      hangover     part        iii       todd   phillips
#
#              6              7        8             9   ...                 44  \
# ...

# %%
import numpy as np
[i for i in list(arm_data.iloc[1,:]) if str(i) != 'nan']
# Out:
# ['entourage',
#  'doug',
#  'ellin',
#  'adrian',
#  'grenier',
#  'kevin',
#  'connolly',
#  'jerry',
#  'ferrara',
#  'kevin',
#  'dillon',
#  'comedy',
#  'navigates',
#  'vapid',
#  'terrain',
#  'close',
#  'circle',
#  'friends',
#  'trusty',
#  'agent',
#  'harper',
#  'lees',
#  'watchmen',
#  'infused',
#  'with',
#  'religious',
#  'symbolism',
#  'cathy',
#  'lynn',
#  'grossman',
#  'religion',
#  'news',
#  'service',
#  'new',
#  'book',
#  'go',
#  'infused',
#  'religious',
#  'life',
#  'christian',
#  'moral',
#  'argument',
#  'title']

# %%
with open('arm_data.txt','w') as f:
    for i in range(0,len(arm_data)):
        print(i)
        a = ",".join([i for i in list(arm_data.iloc[1,:]) if str(i) != 'nan'])
        print(a)
        f.write(a)
        f.write('/n')
    f.close()
# Out:
# 0
# entourage,doug,ellin,adrian,grenier,kevin,connolly,jerry,ferrara,kevin,dillon,comedy,navigates,vapid,terrain,close,circle,friends,trusty,agent,harper,lees,watchmen,infused,with,religious,symbolism,cathy,lynn,grossman,religion,news,service,new,book,go,infused,religious,life,christian,moral,argument,title
# 1
# entourage,doug,ellin,adrian,grenier,kevin,connolly,jerry,ferrara,kevin,dillon,comedy,navigates,vapid,terrain,close,circle,friends,trusty,agent,harper,lees,watchmen,infused,with,religious,symbolism,cathy,lynn,grossman,religion,news,service,new,book,go,infused,religious,life,christian,moral,argument,title
# 2
# entourage,doug,ellin,adrian,grenier,kevin,connolly,jerry,ferrara,kevin,dillon,comedy,navigates,vapid,terrain,close,circle,friends,trusty,agent,harper,lees,watchmen,infused,with,religious,symbolism,cathy,lynn,grossman,religion,news,service,new,book,go,infused,religious,life,christian,moral,argument,title
# 3
# ...
