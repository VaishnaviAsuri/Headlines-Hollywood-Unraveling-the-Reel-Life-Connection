# %%
#This notebook is dedicated to clean and join all the data obtained from extraction and combination of various Kaggle datasets

# %%
import pandas as pd

df1 = pd.read_csv('movies_with_release_dates1.csv')

# %%
import pandas as pd

df = pd.read_csv('mymoviedb.csv')

# %%
#This is a dataset directly obtained from Kaggle

# %%
df
# Out:
#      Release_Date                                 Title  \
# 0      12/15/2021               Spider-Man: No Way Home
# 1        3/1/2022                            The Batman
# 2       2/25/2022                               No Exit
# 3      11/24/2021                               Encanto
# 4      12/22/2021                        The King's Man
# ...           ...                                   ...
# 9832   10/15/1973                              Badlands
# 9833    10/1/2020                      Violent Delights
# 9834     5/6/2016                          The Offering
# 9835    3/31/2021  The United States vs. Billie Holiday
# 9836    9/23/1984                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
#These are all separate datasets that are obtained from OMDB with 1000 rows each. Let us combine them

# %%
import pandas as pd

# Read the CSV files into DataFrames
df1 = pd.read_csv('movies_with_release_dates_and_plots1.csv')
df2 = pd.read_csv('movies_with_release_dates_and_plots2.csv')
df3 = pd.read_csv('movies_with_release_dates_and_plots3.csv')
df4 = pd.read_csv('movies_with_release_dates_and_plots4.csv')
df5 = pd.read_csv('movies_with_release_dates_and_plots5.csv')
df6 = pd.read_csv('movies_with_release_dates_and_plots6.csv')

# Combine the DataFrames
combined_df = pd.concat([df1, df2, df3, df4, df5, df6], ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('combined.csv', index=False)

# %%
df = pd.read_csv('combined.csv')
df
# Out:
#                                         Movie_Title  Year  \
# 0                                           Kantara  2022
# 1                                   The Dark Knight  2008
# 2     The Lord of the Rings: The Return of the King  2003
# 3                                         Inception  2010
# 4             The Lord of the Rings: The Two Towers  2002
# ...                                             ...   ...
# 5552                                 Disaster Movie  2008
# 5553                        The Hottie & the Nottie  2008
# 5554                           From Justin to Kelly  2003
# 5555                   Superbabies: Baby Geniuses 2  2004
# 5556                 Cumali Ceber: Allah Seni Alsin  2017
#
#                                       Director  \
# 0                                Rishab Shetty
# 1                            Christopher Nolan
# 2                                Peter Jackson
# 3                            Christopher Nolan
# ...

# %%
#From here on we repeat the process with various datasets obtained from OMDB extraction and  do some basic cleaning like 
# removing rows with missing values, rename the columns, reset the index, reshape, append to other datasets, etc.

# %%
# Check for missing values and sum them along the rows
missing_rows = combined_df.isna().sum(axis=1)

# Count the total number of rows with missing values
total_missing_rows = missing_rows.sum()

print(f'Total rows with missing values: {total_missing_rows}')
# Out:
# Total rows with missing values: 775

# %%
combined_df.dropna()
# Out:
#                                         Movie_Title  Year  \
# 0                                           Kantara  2022
# 1                                   The Dark Knight  2008
# 2     The Lord of the Rings: The Return of the King  2003
# 3                                         Inception  2010
# 4             The Lord of the Rings: The Two Towers  2002
# ...                                             ...   ...
# 5552                                 Disaster Movie  2008
# 5553                        The Hottie & the Nottie  2008
# 5554                           From Justin to Kelly  2003
# 5555                   Superbabies: Baby Geniuses 2  2004
# 5556                 Cumali Ceber: Allah Seni Alsin  2017
#
#                                       Director  \
# 0                                Rishab Shetty
# 1                            Christopher Nolan
# 2                                Peter Jackson
# 3                            Christopher Nolan
# ...

# %%
earliest_year = combined_df['Year'].min()

# Find the latest (maximum) year
latest_year = combined_df['Year'].max()

print(f"Earliest year: {earliest_year}")
print(f"Latest year: {latest_year}")

combined_df.to_csv('new_comb.csv', index=False)
# Out:
# Earliest year: 1920
# Latest year: 2022

# %%
dff1= pd.read_csv('dff1_with_release_dates_and_plots.csv')
dff2= pd.read_csv('dff2_with_release_dates_and_plots.csv')
dff3= pd.read_csv('dff3_with_release_dates_and_plots.csv')
dff4= pd.read_csv('dff4_with_release_dates_and_plots.csv')
dff5= pd.read_csv('dff5_with_release_dates_and_plots.csv')
dff6= pd.read_csv('dff6_with_release_dates_and_plots.csv')
dff7= pd.read_csv('dff7_with_release_dates_and_plots.csv')
dff8= pd.read_csv('dff8_with_release_dates_and_plots.csv')
dff9= pd.read_csv('dff9_with_release_dates_and_plots.csv')
dff10= pd.read_csv('dff10_with_release_dates_and_plots.csv')

combined_df1 = pd.concat([dff1, dff2, dff3, dff4, dff5, dff6, dff7, dff8, dff9, dff10], ignore_index=True)

# %% [markdown]
# combined_df1

# %%
combined_df1
# Out:
#      Release_Date                                 Title  \
# 0     17 Dec 2021               Spider-Man: No Way Home
# 1     04 Mar 2022                            The Batman
# 2     25 Feb 2022                               No Exit
# 3     24 Nov 2021                               Encanto
# 4     22 Dec 2021                        The King's Man
# ...           ...                                   ...
# 9660  05 Jan 1974                              Badlands
# 9661          NaN                      Violent Delights
# 9662  13 Jan 2023                          The Offering
# 9663  26 Feb 2021  The United States vs. Billie Holiday
# 9664  23 Sep 1984                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
# Check for missing values and sum them along the rows
missing_rows = combined_df1.isna().sum(axis=1)

# Count the total number of rows with missing values
total_missing_rows = missing_rows.sum()

print(f'Total rows with missing values: {total_missing_rows}')
# Out:
# Total rows with missing values: 1335

# %%
combined_df1.dropna()
combined_df1 = combined_df1[combined_df1['Original_Language'] == 'en']
combined_df1 = combined_df1.drop(columns=['Poster_Url'])
combined_df1 = combined_df1.drop(columns=['Original_Language'])

# %%
combined_df1 = combined_df1.drop(columns=['Popularity', 'Vote_Count', 'Overview'])

# %%
combined_df1
# Out:
#      Release_Date                                 Title Vote_Average  \
# 0     17 Dec 2021               Spider-Man: No Way Home          8.3
# 1     04 Mar 2022                            The Batman          8.1
# 2     25 Feb 2022                               No Exit          6.3
# 3     24 Nov 2021                               Encanto          7.7
# 4     22 Dec 2021                        The King's Man          7.0
# ...           ...                                   ...          ...
# 9659  05 Aug 2016                     The Little Prince          6.6
# 9660  05 Jan 1974                              Badlands          7.6
# 9662  13 Jan 2023                          The Offering          5.0
# 9663  26 Feb 2021  The United States vs. Billie Holiday          6.7
# 9664  23 Sep 1984                               Threads          7.8
#
#                                         Genre  \
# 0          Action, Adventure, Science Fiction
# ...

# %%
from IPython.display import FileLink

# Save the DataFrame as a CSV file
csv_filename = 'combined_df1.csv'
combined_df1.to_csv(csv_filename, index=False)  # Set index=False to exclude the index column

# Display a download link for the CSV file
FileLink(csv_filename)
# Out:
# C:\Users\asuri\OneDrive\Desktop\spotify_api\combined_df1.csv

# %%
d1= pd.read_csv('ddf1_with_movie_details.csv')
d2= pd.read_csv('ddf2_with_movie_details.csv')
d3= pd.read_csv('ddf3_with_movie_details.csv')
d4= pd.read_csv('ddf4_with_movie_details.csv')
d5= pd.read_csv('ddf5_with_movie_details.csv')
d6= pd.read_csv('ddf6_with_movie_details.csv')
d7= pd.read_csv('ddf7_with_movie_details.csv')

combined_df2 = pd.concat([d1, d2, d3, d4, d5, d6, d7], ignore_index=True)

# %%
combined_df2.rename(columns={'Vote_Average': 'Rating'}, inplace=True)
combined_df2
combined_df2.to_csv('combined2.csv', index=False)

# %%
#combined_df.rename(columns={'Movie_Title': 'Title'}, inplace=True)
combined_df = combined_df.drop(columns=['Censor','Total_Gross', 'side_genre'])
combined_df.rename(columns={'main_genre': 'Genre'}, inplace=True) 
combined_df.rename(columns={'Movie_Title': 'Title'}, inplace=True)
combined_df.rename(columns={'Runtime(Mins)': 'Runtime'}, inplace=True)

combined_df
# Out:
#                                               Title  Year  \
# 0                                           Kantara  2022
# 1                                   The Dark Knight  2008
# 2     The Lord of the Rings: The Return of the King  2003
# 3                                         Inception  2010
# 4             The Lord of the Rings: The Two Towers  2002
# ...                                             ...   ...
# 5552                                 Disaster Movie  2008
# 5553                        The Hottie & the Nottie  2008
# 5554                           From Justin to Kelly  2003
# 5555                   Superbabies: Baby Geniuses 2  2004
# 5556                 Cumali Ceber: Allah Seni Alsin  2017
#
#                                       Director  \
# 0                                Rishab Shetty
# 1                            Christopher Nolan
# 2                                Peter Jackson
# 3                            Christopher Nolan
# ...

# %%
import pandas as pd

# Assuming 'combined_df' and 'combined_df2' are your DataFrames
# Replace them with your actual DataFrames

# Combine the two DataFrames while dropping rows with duplicate 'Title' values
combined_df = pd.concat([combined_df, combined_df2], ignore_index=True)
combined_df.drop_duplicates(subset='Title', inplace=True)

# %%
combined_df
# Out:
#                                                 Title  Year  \
# 0                                             Kantara  2022
# 1                                     The Dark Knight  2008
# 2       The Lord of the Rings: The Return of the King  2003
# 3                                           Inception  2010
# 4               The Lord of the Rings: The Two Towers  2002
# ...                                               ...   ...
# 10543                                  Minions: Puppy   NaN
# 10545                                           Havoc  2005
# 10549           Batman: Return of the Caped Crusaders  2016
# 10551  One Crazy Summer: A Look Back at Gravity Falls  2018
# 10552                     Gunfight at the O.K. Corral  1957
#
#                 Director                                             Actors  \
# 0          Rishab Shetty  Rishab Shetty, Sapthami Gowda, Kishore Kumar G...
# 1      Christopher Nolan  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# ...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Replace 'df' with your actual DataFrame

# Check for NaN values in each row and sum them
num_rows_with_na = combined_df.isna().sum(axis=1).sum()
num_rows_with_na
# Out:
# 1698

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Replace 'df' with your actual DataFrame

# Drop rows with NaN values
combined_df.dropna(inplace=True)

# %%
combined_df.reset_index(drop=True, inplace=True)
combined_df
# Out:
#                                                Title  Year           Director  \
# 0                                            Kantara  2022      Rishab Shetty
# 1                                    The Dark Knight  2008  Christopher Nolan
# 2      The Lord of the Rings: The Return of the King  2003      Peter Jackson
# 3                                          Inception  2010  Christopher Nolan
# 4              The Lord of the Rings: The Two Towers  2002      Peter Jackson
# ...                                              ...   ...                ...
# 7027                              Beyond White Space  2018      Ken Locsmandi
# 7028                                           Havoc  2005     Barbara Kopple
# 7029           Batman: Return of the Caped Crusaders  2016       Rick Morales
# 7030  One Crazy Summer: A Look Back at Gravity Falls  2018         Brian Ward
# 7031                     Gunfight at the O.K. Corral  1957       John Sturges
#
# ...

# %%
new_df= pd.read_csv('top_1000_popular_movies_tmdb.csv')
new_df = new_df[new_df['original_language'] == 'English']

new_df.rename(columns={'vote_average': 'Rating'}, inplace=True)
new_df.rename(columns={'overview': 'Plot_Summary'}, inplace=True)
new_df.rename(columns={'genres': 'Genre'}, inplace=True)
new_df.rename(columns={'title': 'Title'}, inplace=True)
new_df.rename(columns={'runtime': 'Runtime'}, inplace=True)
new_df.rename(columns={'release_date': 'Release_Date'}, inplace=True)

new_df = new_df.drop(columns=['id', 'original_language', 'vote_count', 'popularity', 'budget', 'production_companies', 'revenue', 'tagline'])

# %%
new_df
# Out:
#       Unnamed: 0                                Title Release_Date  \
# 0              0                               Fast X    5/17/2023
# 1              1                 John Wick: Chapter 4    3/22/2023
# 2              2          The Super Mario Bros. Movie     4/5/2023
# 3              3  Spider-Man: Across the Spider-Verse    5/31/2023
# 4              4                             Hypnotic    5/11/2023
# ...          ...                                  ...          ...
# 9994        9993                              Shut In   11/11/2016
# 9997        9996            Dead Men Don't Wear Plaid    5/21/1982
# 9998        9997                            Communion   11/10/1989
# 9999        9998                                 Tess    10/6/1979
# 10000       9999       The Possession of Michael King    8/14/2014
#
#                                                    Genre  Rating  \
# 0                        ['Action', 'Crime', 'Thriller']     7.4
# ...

# %%
import pandas as pd

# Assuming 'combined_df2' and 'new_df' are your DataFrames
# Replace them with your actual DataFrames

# Identify matching 'Title' values
matching_titles = set(combined_df['Title']).intersection(new_df['Title'])

# Filter 'new_df' to retain only non-matching rows
new_df = new_df[~new_df['Title'].isin(matching_titles)]

# Both 'combined_df2' and 'new_df' now contain non-matching rows

# %%
new_df.reset_index(drop=True, inplace=True)
#new_df = new_df.drop(columns=['Unnamed: 0'])

new_df
# Out:
#      Unnamed: 0                                      Title Release_Date  \
# 0             0                                     Fast X    5/17/2023
# 1             1                       John Wick: Chapter 4    3/22/2023
# 2             2                The Super Mario Bros. Movie     4/5/2023
# 3             3        Spider-Man: Across the Spider-Verse    5/31/2023
# 4             6                            The Black Demon    4/26/2023
# ...         ...                                        ...          ...
# 2012       9992  The Meyerowitz Stories (New and Selected)   10/13/2017
# 2013       9996                  Dead Men Don't Wear Plaid    5/21/1982
# 2014       9997                                  Communion   11/10/1989
# 2015       9998                                       Tess    10/6/1979
# 2016       9999             The Possession of Michael King    8/14/2014
#
#                                                   Genre  Rating  \
# ...

# %%
nd1=pd.read_csv("nd1_with_movie_details.csv")
nd2=pd.read_csv("nd2_with_movie_details.csv")
nd3=pd.read_csv("nd3_with_movie_details.csv")
new_df= pd.concat([nd1, nd2, nd3], ignore_index=True)

# %%
num_nan_values = new_df['Release_Date'].isna().sum()

print(f"Number of NaN values in 'Release_Date' column: {num_nan_values}")
# Out:
# Number of NaN values in 'Release_Date' column: 18

# %%
combined_df = pd.concat([combined_df, new_df], ignore_index=True)
combined_df
# Out:
#                                               Title    Year  \
# 0                                           Kantara    2022
# 1                                   The Dark Knight    2008
# 2     The Lord of the Rings: The Return of the King    2003
# 3                                         Inception    2010
# 4             The Lord of the Rings: The Two Towers    2002
# ...                                             ...     ...
# 9042      The Meyerowitz Stories (New and Selected)     NaN
# 9043                      Dead Men Don't Wear Plaid  1982.0
# 9044                                      Communion  1989.0
# 9045                                           Tess  1979.0
# 9046                 The Possession of Michael King  2014.0
#
#                Director                                             Actors  \
# 0         Rishab Shetty  Rishab Shetty, Sapthami Gowda, Kishore Kumar G...
# 1     Christopher Nolan  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# ...

# %%
import pandas as pd

# Assuming 'combined_df' is your DataFrame
# Replace 'combined_df' with your actual DataFrame

# Convert the 'Year' column to numeric (integer or float)
combined_df['Year'] = pd.to_numeric(combined_df['Year'], errors='coerce')
combined_df
# Out:
#                                               Title    Year  \
# 0                                           Kantara  2022.0
# 1                                   The Dark Knight  2008.0
# 2     The Lord of the Rings: The Return of the King  2003.0
# 3                                         Inception  2010.0
# 4             The Lord of the Rings: The Two Towers  2002.0
# ...                                             ...     ...
# 9042      The Meyerowitz Stories (New and Selected)     NaN
# 9043                      Dead Men Don't Wear Plaid  1982.0
# 9044                                      Communion  1989.0
# 9045                                           Tess  1979.0
# 9046                 The Possession of Michael King  2014.0
#
#                Director                                             Actors  \
# 0         Rishab Shetty  Rishab Shetty, Sapthami Gowda, Kishore Kumar G...
# 1     Christopher Nolan  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# ...

# %%
csv_filename = 'big_df.csv'
combined_df.to_csv(csv_filename, index=False)

# %%
import pandas as pd

# Assuming 'combined_df' is your DataFrame
# Replace 'combined_df' with your actual DataFrame

# Convert 'Release_Date' column to datetime objects with the current format
combined_df['Release_Date'] = pd.to_datetime(combined_df['Release_Date'], format='%d-%b-%y', errors='coerce')

# Format 'Release_Date' to the desired standard format
combined_df['Release_Date'] = combined_df['Release_Date'].dt.strftime('%Y-%m-%d')

# %%
combined_df
# Out:
#                                               Title    Year  \
# 0                                           Kantara  2022.0
# 1                                   The Dark Knight  2008.0
# 2     The Lord of the Rings: The Return of the King  2003.0
# 3                                         Inception  2010.0
# 4             The Lord of the Rings: The Two Towers  2002.0
# ...                                             ...     ...
# 9042      The Meyerowitz Stories (New and Selected)     NaN
# 9043                      Dead Men Don't Wear Plaid  1982.0
# 9044                                      Communion  1989.0
# 9045                                           Tess  1979.0
# 9046                 The Possession of Michael King  2014.0
#
#                Director                                             Actors  \
# 0         Rishab Shetty  Rishab Shetty, Sapthami Gowda, Kishore Kumar G...
# 1     Christopher Nolan  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# ...

# %%
import pandas as pd

# Assuming 'combined_df' is your DataFrame
# Replace 'combined_df' with your actual DataFrame

# Check the number of NaN values in the 'Release_Date' column
num_nan_values = combined_df['Release_Date'].isna().sum()

print(f"Number of NaN values in 'Release_Date' column: {num_nan_values}")
# Out:
# Number of NaN values in 'Release_Date' column: 10454

# %%
combined_df.sort_values(by='Release_Date', inplace=True)
combined_df.reset_index(drop=True, inplace=True)


# Check how many values in the 'Year' column are from '2012' and later
count_values_after_2012 = (combined_df['Year'] >= 2012).sum()

print(f"Number of values in the 'Year' column from 2012 and later: {count_values_after_2012}")
combined_df
# Out:
# Number of values in the 'Year' column from 2012 and later: 5061
#                                                Title    Year  \
# 0                                            Kantara  2022.0
# 1                                    The Dark Knight  2008.0
# 2      The Lord of the Rings: The Return of the King  2003.0
# 3                                          Inception  2010.0
# 4              The Lord of the Rings: The Two Towers  2002.0
# ...                                              ...     ...
# 10449                              Love & Basketball  2000.0
# 10450                      Dead Men Don't Wear Plaid  1982.0
# 10451                                      Communion  1989.0
# 10452                                           Tess  1979.0
# 10453                 The Possession of Michael King  2014.0
#
#                     Director  \
# 0              Rishab Shetty
# 1          Christopher Nolan
# 2              Peter Jackson
# 3          Christopher Nolan
# ...

# %%
news_df= pd.read_csv("output.csv")
news_df = news_df.drop(columns=['link'])
news_df
# Out:
#                                                  headline          category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...         U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...         U.S. NEWS
# 2       23 Of The Funniest Tweets About Cats And Dogs ...            COMEDY
# 3       The Funniest Tweets From Parents This Week (Se...         PARENTING
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...         U.S. NEWS
# ...                                                   ...               ...
# 209522  RIM CEO Thorsten Heins' 'Significant' Plans Fo...  Reuters, Reuters
# 209523  Maria Sharapova Stunned By Victoria Azarenka I...               NaN
# 209524  Giants Over Patriots, Jets Over Colts Among  M...               NaN
# 209525  Aldon Smith Arrested: 49ers Linebacker Busted ...               NaN
# 209526  Dwight Howard Rips Teammates After Magic Loss ...               NaN
#
# ...

# %%
# Perform an inner join based on the 'date' and 'Release_Date' columns
merged_df = news_df.merge(combined_df, left_on='date', right_on='Release_Date', how='inner')

# %%
merged_df.reset_index(drop=True, inplace=True)
merged_df
# Out:
#                                                  headline          category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...         U.S. NEWS
# 1       Over 4 Million Americans Roll Up Sleeves For O...         U.S. NEWS
# 2       Over 4 Million Americans Roll Up Sleeves For O...         U.S. NEWS
# 3       Over 4 Million Americans Roll Up Sleeves For O...         U.S. NEWS
# 4       Over 4 Million Americans Roll Up Sleeves For O...         U.S. NEWS
# ...                                                   ...               ...
# 205388                         Work Hard For Denser Bones  Meredith Melnick
# 205389  Madeleine Telfer, Cancer Survivor, Celebrates ...   Jessica Samakow
# 205390  TSA Agent Accused Of Stealing iPads From Trave...               NaN
# 205391  Anna Dello Russo Wigs Out For Radio Deejay's 3...       Dana Oliver
# 205392  Kristen Bell's Adorable Meltdown: Why We Cry W...               NaN
#
# ...

# %%
import pandas as pd

# Assuming 'news_df' and 'combined_df' are your DataFrames
# Replace them with your actual DataFrames

# Step 1: Sort both datasets by the date column
news_df.sort_values(by='date', inplace=True)
combined_df.sort_values(by='Release_Date', inplace=True)

# Step 2: Create a dictionary to map dates to the count of movies released
movie_count_dict = combined_df['Release_Date'].value_counts().to_dict()

# Initialize variables to keep track of headlines assigned to each date
assigned_headlines = {}
remaining_headlines = []

# Step 3 and 4: Iterate through 'news_df' and assign headlines to dates
for index, row in news_df.iterrows():
    date = row['date']
    if date in movie_count_dict:
        movie_count = movie_count_dict[date]
        if date not in assigned_headlines:
            assigned_headlines[date] = []
        if len(assigned_headlines[date]) < movie_count:
            assigned_headlines[date].append(row['headline'])
        else:
            remaining_headlines.append(row['headline'])

# Create a new DataFrame with assigned headlines
assigned_headlines_df = pd.DataFrame({
    'date': [date for date, headlines in assigned_headlines.items() for _ in headlines],
    'headline': [headline for headlines in assigned_headlines.values() for headline in headlines]
})

# 'assigned_headlines_df' now contains headlines assigned to dates

# %%
assigned_headlines_df
# Out:
#             date                                           headline
# 0     2012-02-01  CFDA's 'The Fashion Fund' On Hulu: Diane Von F...
# 1     2012-02-02          Saying Yes To The Dress With Randy Fenoli
# 2     2012-02-02  Heart Health: 13 Foods With Cardiovascular Ben...
# 3     2012-02-03  Marge Fitzsimmons, 36-Year-Old LeRoy Woman, Ha...
# 4     2012-02-03  Best Blogger Looks Of The Week: The Shoes Edit...
# ...          ...                                                ...
# 3875  2022-09-21  World Cup Captains Want To Wear Rainbow Armban...
# 3876  2022-09-23  The Funniest Tweets From Parents This Week (Se...
# 3877  2022-09-23  23 Of The Funniest Tweets About Cats And Dogs ...
# 3878  2022-09-23  American Airlines Flyer Charged, Banned For Li...
# 3879  2022-09-23  Over 4 Million Americans Roll Up Sleeves For O...
#
# [3880 rows x 2 columns]

# %%
import pandas as pd

# Assuming 'news_df' and 'combined_df' are your DataFrames
# Replace them with your actual DataFrames

# Convert 'date' and 'Release_Date' columns to datetime objects
news_df['date'] = pd.to_datetime(news_df['date'])
combined_df['Release_Date'] = pd.to_datetime(combined_df['Release_Date'])

# Sort 'news_df' and 'combined_df' by their respective date columns
news_df.sort_values(by='date', inplace=True)
combined_df.sort_values(by='Release_Date', inplace=True)

# Count rows with the same dates in 'news_df'
news_df_date_counts = news_df.groupby('date').size().reset_index(name='news_count')

# Count rows with the same dates in 'combined_df'
combined_df_date_counts = combined_df.groupby('Release_Date').size().reset_index(name='movie_count')

# Print the counts for 'news_df' and 'combined_df'
print("Count of rows with the same dates in 'news_df':")
print(news_df_date_counts)

print("\nCount of rows with the same dates in 'combined_df':")
print(combined_df_date_counts)
# Out:
# Count of rows with the same dates in 'news_df':
#            date  news_count
# 0    2012-01-28          66
# 1    2012-01-29          65
# 2    2012-01-30         100
# 3    2012-01-31         100
# 4    2012-02-01         100
# ...         ...         ...
# 3885 2022-09-19           6
# 3886 2022-09-20           6
# 3887 2022-09-21           6
# 3888 2022-09-22           5
# 3889 2022-09-23           4
#
# [3890 rows x 2 columns]
#
# Count of rows with the same dates in 'combined_df':
#      Release_Date  movie_count
# 0      1915-02-08            2
# 1      1924-05-04            2
# 2      1929-01-05            1
# 3      1930-09-06            1
# 4      1931-07-16            2
# ...           ...          ...
# 4377   2072-09-26            1
# 4378   2072-12-11            1
# 4379   2072-12-13            1
# 4380   2072-12-16            1
# 4381   2072-12-21            1
#
# [4382 rows x 2 columns]
