# %%
#This whole notebook is dedicated to standardizing the date formats.
#I tried to dvide the datasets based on the date formats and then standardize each of them and finally combine it all into
# a big dataset called 'combined_all'

# %%
import pandas as pd

# %%
new_comb= pd.read_csv("new_comb.csv")
new_comb
# Out:
#                                         Movie_Title  Year  \
# 0                                           Kantara  2022
# 1                                   The Dark Knight  2008
# 2     The Lord of the Rings: The Return of the King  2003
# 3                                         Inception  2010
# 4             The Lord of the Rings: The Two Towers  2002
# ...                                             ...   ...
# 5552                                 Disaster Movie  2008
# 5553                        The Hottie & the Nottie  2008
# 5554                           From Justin to Kelly  2003
# 5555                   Superbabies: Baby Geniuses 2  2004
# 5556                 Cumali Ceber: Allah Seni Alsin  2017
#
#                                       Director  \
# 0                                Rishab Shetty
# 1                            Christopher Nolan
# 2                                Peter Jackson
# 3                            Christopher Nolan
# 4                                Peter Jackson
# ...                                        ...
# 5552  Directors:Jason Friedberg, Aaron Seltzer
# 5553                                Tom Putnam
# 5554                             Robert Iscove
# 5555                                 Bob Clark
# 5556                                Gökhan Gök
#
#                                                  Actors  Rating  \
# 0     Rishab Shetty, Sapthami Gowda, Kishore Kumar G...     9.3
# 1     Christian Bale, Heath Ledger, Aaron Eckhart, M...     9.0
# 2     Elijah Wood, Viggo Mortensen, Ian McKellen, Or...     9.0
# 3     Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...     8.8
# 4     Elijah Wood, Ian McKellen, Viggo Mortensen, Or...     8.8
# ...                                                 ...     ...
# 5552  Carmen Electra, Vanessa Lachey, Nicole Parker,...     1.9
# 5553  Paris Hilton, Joel David Moore, Christine Laki...     1.9
# 5554  Kelly Clarkson, Justin Guarini, Katherine Bail...     1.9
# 5555  Jon Voight, Scott Baio, Vanessa Angel, Skyler ...     1.5
# 5556  Halil Söyletmez, Doga Konakoglu, Emre Keskin, ...     1.0
#
#       Runtime(Mins)     Censor   Total_Gross main_genre           side_genre  \
# 0               148         UA  Gross Unkown     Action    Adventure,  Drama
# 1               152         UA      $534.86M     Action        Crime,  Drama
# 2               201          U      $377.85M     Action    Adventure,  Drama
# 3               148         UA      $292.58M     Action   Adventure,  Sci-Fi
# 4               179         UA      $342.55M     Action    Adventure,  Drama
# ...             ...        ...           ...        ...                  ...
# 5552             87      PG-13       $14.19M     Comedy               Sci-Fi
# 5553             91      PG-13        $0.03M     Comedy              Romance
# 5554             81         PG        $4.92M     Comedy    Musical,  Romance
# 5555             88         PG        $9.11M     Comedy      Family,  Sci-Fi
# 5556            100  Not Rated  Gross Unkown     Comedy               Comedy
#
#      Release_Date                                       Plot_Summary
# 0       30-Sep-22  When greed paves the way for betrayal, schemin...
# 1       18-Jul-08  When the menace known as the Joker wreaks havo...
# 2       17-Dec-03  Gandalf and Aragorn lead the World of Men agai...
# 3       16-Jul-10  A thief who steals corporate secrets through t...
# 4       18-Dec-02  While Frodo and Sam edge closer to Mordor with...
# ...           ...                                                ...
# 5552    29-Aug-08  Over the course of one evening, an unsuspectin...
# 5553    21-Feb-08  A woman agrees to go on a date with a man only...
# 5554    20-Jun-03  A waitress from Texas and a college student fr...
# 5555    27-Aug-04  A group of smart-talking toddlers find themsel...
# 5556     4-Aug-17  Cumali Ceber goes to a vacation with his child...
#
# [5557 rows x 12 columns]

# %%
# Extract the year information from the 'Release_Date' column and create a new 'Year' column
#combined_df['Year'] = pd.to_datetime(combined_df['Release_Date'], errors='coerce').dt.year

# Find the earliest (minimum) year
earliest_year = new_comb['Release_Date'].min()

# Find the latest (maximum) year
latest_year = new_comb['Release_Date'].max()

print(f"Earliest year: {earliest_year}")
print(f"Latest year: {latest_year}")
# Out:
# Earliest year: 1921-02-06 00:00:00
# Latest year: 2022-12-20 00:00:00

# %%
import pandas as pd

# Assuming 'new_comb' is your DataFrame
# Replace 'new_comb' with your actual DataFrame

# Convert 'Year' column to a four-digit year format
new_comb['Year'] = new_comb['Year'].apply(lambda x: '20' + str(x) if len(str(x)) == 2 else str(x))

# Function to parse the 'Release_Date' column and standardize the date
def parse_and_standardize_date(row):
    release_date = row['Release_Date']
    year = row['Year']
    if pd.notna(release_date):
        date_parts = release_date.split('-')
        if len(date_parts) == 3:
            day, month = date_parts[:2]
            standardized_date = f"{year}-{month}-{day}"
            return pd.to_datetime(standardized_date, format='%Y-%b-%d', errors='coerce')
    return pd.NaT

# Apply the function to create the 'Standardized_Date' column
new_comb['Release_Date'] = new_comb.apply(parse_and_standardize_date, axis=1)

# Drop the intermediate columns if not needed
#new_comb.drop(['Year'], axis=1, inplace=True)

# %%
missing_values_count = new_comb['Release_Date'].isna().sum()

print(f"Number of missing values in the 'Release_Date' column: {missing_values_count}")
# Out:
# Number of missing values in the 'Release_Date' column: 371

# %%
new_comb = new_comb.drop(columns=['Censor','Total_Gross', 'side_genre'])
new_comb.rename(columns={'main_genre': 'Genre'}, inplace=True) 
new_comb.rename(columns={'Movie_Title': 'Title'}, inplace=True)
new_comb.rename(columns={'Runtime(Mins)': 'Runtime'}, inplace=True)

new_comb
# Out:
#                                               Title  Year  \
# 0                                           Kantara  2022
# 1                                   The Dark Knight  2008
# 2     The Lord of the Rings: The Return of the King  2003
# 3                                         Inception  2010
# 4             The Lord of the Rings: The Two Towers  2002
# ...                                             ...   ...
# 5552                                 Disaster Movie  2008
# 5553                        The Hottie & the Nottie  2008
# 5554                           From Justin to Kelly  2003
# 5555                   Superbabies: Baby Geniuses 2  2004
# 5556                 Cumali Ceber: Allah Seni Alsin  2017
#
#                                       Director  \
# 0                                Rishab Shetty
# 1                            Christopher Nolan
# 2                                Peter Jackson
# 3                            Christopher Nolan
# 4                                Peter Jackson
# ...                                        ...
# 5552  Directors:Jason Friedberg, Aaron Seltzer
# 5553                                Tom Putnam
# 5554                             Robert Iscove
# 5555                                 Bob Clark
# 5556                                Gökhan Gök
#
#                                                  Actors  Rating  Runtime  \
# 0     Rishab Shetty, Sapthami Gowda, Kishore Kumar G...     9.3      148
# 1     Christian Bale, Heath Ledger, Aaron Eckhart, M...     9.0      152
# 2     Elijah Wood, Viggo Mortensen, Ian McKellen, Or...     9.0      201
# 3     Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...     8.8      148
# 4     Elijah Wood, Ian McKellen, Viggo Mortensen, Or...     8.8      179
# ...                                                 ...     ...      ...
# 5552  Carmen Electra, Vanessa Lachey, Nicole Parker,...     1.9       87
# 5553  Paris Hilton, Joel David Moore, Christine Laki...     1.9       91
# 5554  Kelly Clarkson, Justin Guarini, Katherine Bail...     1.9       81
# 5555  Jon Voight, Scott Baio, Vanessa Angel, Skyler ...     1.5       88
# 5556  Halil Söyletmez, Doga Konakoglu, Emre Keskin, ...     1.0      100
#
#        Genre Release_Date                                       Plot_Summary
# 0     Action   2022-09-30  When greed paves the way for betrayal, schemin...
# 1     Action   2008-07-18  When the menace known as the Joker wreaks havo...
# 2     Action   2003-12-17  Gandalf and Aragorn lead the World of Men agai...
# 3     Action   2010-07-16  A thief who steals corporate secrets through t...
# 4     Action   2002-12-18  While Frodo and Sam edge closer to Mordor with...
# ...      ...          ...                                                ...
# 5552  Comedy   2008-08-29  Over the course of one evening, an unsuspectin...
# 5553  Comedy   2008-02-21  A woman agrees to go on a date with a man only...
# 5554  Comedy   2003-06-20  A waitress from Texas and a college student fr...
# 5555  Comedy   2004-08-27  A group of smart-talking toddlers find themsel...
# 5556  Comedy   2017-08-04  Cumali Ceber goes to a vacation with his child...
#
# [5557 rows x 9 columns]

# %%
import pandas as pd

# Assuming 'new_comb' is your DataFrame
# Replace 'new_comb' with your actual DataFrame

# Find the earliest (minimum) year
earliest_year = new_comb['Year'].min()

# Find the latest (maximum) year
latest_year = new_comb['Year'].max()

print(f"Earliest year: {earliest_year}")
print(f"Latest year: {latest_year}")
# Out:
# Earliest year: 1920
# Latest year: 2022

# %%
#This is the second dataset that needed the dates to be standardized

# %%
combined_df2= pd.read_csv("combined2.csv")
combined_df2
# Out:
#      Release_Date                                 Title  Rating  \
# 0     17 Dec 2021               Spider-Man: No Way Home     8.3
# 1     04 Mar 2022                            The Batman     8.1
# 2     25 Feb 2022                               No Exit     6.3
# 3     24 Nov 2021                               Encanto     7.7
# 4     22 Dec 2021                        The King's Man     7.0
# ...           ...                                   ...     ...
# 5781  05 Aug 2016                     The Little Prince     6.6
# 5782  05 Jan 1974                              Badlands     7.6
# 5783  13 Jan 2023                          The Offering     5.0
# 5784  26 Feb 2021  The United States vs. Billie Holiday     6.7
# 5785  23 Sep 1984                               Threads     7.8
#
#                                         Genre  \
# 0          Action, Adventure, Science Fiction
# 1                    Crime, Mystery, Thriller
# 2                                    Thriller
# 3          Animation, Comedy, Family, Fantasy
# 4            Action, Adventure, Thriller, War
# ...                                       ...
# 5781  Science Fiction, Fantasy, Family, Music
# 5782                             Drama, Crime
# 5783                Mystery, Thriller, Horror
# 5784                    Music, Drama, History
# 5785              War, Drama, Science Fiction
#
#                                            Plot_Summary  \
# 0     With Spider-Man's identity now revealed, Peter...
# 1     When a sadistic serial killer begins murdering...
# 2     During a blizzard and stranded at an isolated ...
# 3     A Colombian teenage girl has to face the frust...
# 4     In the early years of the 20th century, the Ki...
# ...                                                 ...
# 5781  A little girl lives in a very grown-up world w...
# 5782  An impressionable teenage girl from a dead-end...
# 5783  A family struggling with loss find themselves ...
# 5784  Follows Holiday during her career as she is ta...
# 5785  The effects of a nuclear holocaust on the work...
#
#                                             Director  \
# 0                                          Jon Watts
# 1                                        Matt Reeves
# 2                                       Damien Power
# 3     Jared Bush, Byron Howard, Charise Castro Smith
# 4                                     Matthew Vaughn
# ...                                              ...
# 5781                                    Mark Osborne
# 5782                                 Terrence Malick
# 5783                                     Oliver Park
# 5784                                     Lee Daniels
# 5785                                    Mick Jackson
#
#                                                  Actors  Year  Runtime
# 0            Tom Holland, Zendaya, Benedict Cumberbatch  2021  148 min
# 1         Robert Pattinson, Zoë Kravitz, Jeffrey Wright  2022  176 min
# 2         Havana Rose Liu, Danny Ramirez, David Rysdahl  2022   95 min
# 3     Stephanie Beatriz, María Cecilia Botero, John ...  2021  102 min
# 4             Ralph Fiennes, Gemma Arterton, Rhys Ifans  2021  131 min
# ...                                                 ...   ...      ...
# 5781        Jeff Bridges, Mackenzie Foy, Rachel McAdams  2015  108 min
# 5782           Martin Sheen, Sissy Spacek, Warren Oates  1973   94 min
# 5783               Nick Blood, Emily Wiseman, Paul Kaye  2022   93 min
# 5784        Andra Day, Trevante Rhodes, Garrett Hedlund  2021  126 min
# 5785       Karen Meagher, Reece Dinsdale, David Brierly  1984  112 min
#
# [5786 rows x 9 columns]

# %%
missing_values_count = combined_df2['Release_Date'].isna().sum()

print(f"Number of missing values in the 'Release_Date' column: {missing_values_count}")
# Out:
# Number of missing values in the 'Release_Date' column: 199

# %%
import pandas as pd

# Assuming 'combined_df2' is your DataFrame
# Replace 'combined_df2' with your actual DataFrame

# Convert 'Year' column to a four-digit year format
combined_df2['Year'] = combined_df2['Year'].apply(lambda x: '20' + str(x) if len(str(x)) == 2 else str(x))

# Function to parse the 'Release_Date' column and standardize the date
def parse_and_standardize_date(row):
    release_date = row['Release_Date']
    year = row['Year']
    if pd.notna(release_date):
        date_parts = release_date.split(' ')
        if len(date_parts) == 3:
            day, month, year = date_parts
            month = month[:3]  # Extract the first three letters of the month
            standardized_date = f"{year}-{month}-{day}"
            return pd.to_datetime(standardized_date, format='%Y-%b-%d', errors='coerce')
    return pd.NaT

# Apply the function to create the 'Standardized_Date' column
combined_df2['Release_Date'] = combined_df2.apply(parse_and_standardize_date, axis=1)

# Drop the intermediate columns if not needed
#combined_df2.drop(['Year'], axis=1, inplace=True)

# %%
combined_df2
# Out:
#      Release_Date                                 Title  Rating  \
# 0      2021-12-17               Spider-Man: No Way Home     8.3
# 1      2022-03-04                            The Batman     8.1
# 2      2022-02-25                               No Exit     6.3
# 3      2021-11-24                               Encanto     7.7
# 4      2021-12-22                        The King's Man     7.0
# ...           ...                                   ...     ...
# 5781   2016-08-05                     The Little Prince     6.6
# 5782   1974-01-05                              Badlands     7.6
# 5783   2023-01-13                          The Offering     5.0
# 5784   2021-02-26  The United States vs. Billie Holiday     6.7
# 5785   1984-09-23                               Threads     7.8
#
#                                         Genre  \
# 0          Action, Adventure, Science Fiction
# 1                    Crime, Mystery, Thriller
# 2                                    Thriller
# 3          Animation, Comedy, Family, Fantasy
# 4            Action, Adventure, Thriller, War
# ...                                       ...
# 5781  Science Fiction, Fantasy, Family, Music
# 5782                             Drama, Crime
# 5783                Mystery, Thriller, Horror
# 5784                    Music, Drama, History
# 5785              War, Drama, Science Fiction
#
#                                            Plot_Summary  \
# 0     With Spider-Man's identity now revealed, Peter...
# 1     When a sadistic serial killer begins murdering...
# 2     During a blizzard and stranded at an isolated ...
# 3     A Colombian teenage girl has to face the frust...
# 4     In the early years of the 20th century, the Ki...
# ...                                                 ...
# 5781  A little girl lives in a very grown-up world w...
# 5782  An impressionable teenage girl from a dead-end...
# 5783  A family struggling with loss find themselves ...
# 5784  Follows Holiday during her career as she is ta...
# 5785  The effects of a nuclear holocaust on the work...
#
#                                             Director  \
# 0                                          Jon Watts
# 1                                        Matt Reeves
# 2                                       Damien Power
# 3     Jared Bush, Byron Howard, Charise Castro Smith
# 4                                     Matthew Vaughn
# ...                                              ...
# 5781                                    Mark Osborne
# 5782                                 Terrence Malick
# 5783                                     Oliver Park
# 5784                                     Lee Daniels
# 5785                                    Mick Jackson
#
#                                                  Actors  Year  Runtime
# 0            Tom Holland, Zendaya, Benedict Cumberbatch  2021  148 min
# 1         Robert Pattinson, Zoë Kravitz, Jeffrey Wright  2022  176 min
# 2         Havana Rose Liu, Danny Ramirez, David Rysdahl  2022   95 min
# 3     Stephanie Beatriz, María Cecilia Botero, John ...  2021  102 min
# 4             Ralph Fiennes, Gemma Arterton, Rhys Ifans  2021  131 min
# ...                                                 ...   ...      ...
# 5781        Jeff Bridges, Mackenzie Foy, Rachel McAdams  2015  108 min
# 5782           Martin Sheen, Sissy Spacek, Warren Oates  1973   94 min
# 5783               Nick Blood, Emily Wiseman, Paul Kaye  2022   93 min
# 5784        Andra Day, Trevante Rhodes, Garrett Hedlund  2021  126 min
# 5785       Karen Meagher, Reece Dinsdale, David Brierly  1984  112 min
#
# [5786 rows x 9 columns]

# %%
missing_values_count = combined_df2['Release_Date'].isna().sum()

print(f"Number of missing values in the 'Release_Date' column: {missing_values_count}")
# Out:
# Number of missing values in the 'Release_Date' column: 199

# %%
#For this dataset, since we had three different date formats in the same dataset, its best to divide it into three datasets, 
#standardize the dates and join them again. Conditionally changinging the dataset based on the format was not working for 
#some reason. Thus, I decided this is the best solution

# %%
big_df= pd.read_csv("big_df.csv")
big_df
# Out:
#                                               Title    Year  \
# 0                                           Kantara    2022
# 1                                   The Dark Knight    2008
# 2     The Lord of the Rings: The Return of the King    2003
# 3                                         Inception    2010
# 4             The Lord of the Rings: The Two Towers    2002
# ...                                             ...     ...
# 9042      The Meyerowitz Stories (New and Selected)     NaN
# 9043                      Dead Men Don't Wear Plaid  1982.0
# 9044                                      Communion  1989.0
# 9045                                           Tess  1979.0
# 9046                 The Possession of Michael King  2014.0
#
#                Director                                             Actors  \
# 0         Rishab Shetty  Rishab Shetty, Sapthami Gowda, Kishore Kumar G...
# 1     Christopher Nolan  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 2         Peter Jackson  Elijah Wood, Viggo Mortensen, Ian McKellen, Or...
# 3     Christopher Nolan  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 4         Peter Jackson  Elijah Wood, Ian McKellen, Viggo Mortensen, Or...
# ...                 ...                                                ...
# 9042                NaN                                                NaN
# 9043        Carl Reiner               Steve Martin, Rachel Ward, Alan Ladd
# 9044      Philippe Mora  Christopher Walken, Lindsay Crouse, Frances St...
# 9045     Roman Polanski        Nastassja Kinski, Peter Firth, Leigh Lawson
# 9046         David Jung           Shane Johnson, Ella Anderson, Cara Pifko
#
#       Rating Runtime                                              Genre  \
# 0        9.3     148                                             Action
# 1        9.0     152                                             Action
# 2        9.0     201                                             Action
# 3        8.8     148                                             Action
# 4        8.8     179                                             Action
# ...      ...     ...                                                ...
# 9042     6.5     112                                ['Comedy', 'Drama']
# 9043     6.6      89                              ['Comedy', 'Mystery']
# 9044     5.3     103  ['Drama', 'Horror', 'Science Fiction', 'Thrill...
# 9045     7.0     186                               ['Drama', 'Romance']
# 9046     6.1      83                                         ['Horror']
#
#      Release_Date                                       Plot_Summary
# 0       30-Sep-22  When greed paves the way for betrayal, schemin...
# 1       18-Jul-08  When the menace known as the Joker wreaks havo...
# 2       17-Dec-03  Gandalf and Aragorn lead the World of Men agai...
# 3       16-Jul-10  A thief who steals corporate secrets through t...
# 4       18-Dec-02  While Frodo and Sam edge closer to Mordor with...
# ...           ...                                                ...
# 9042   10/13/2017  An estranged family gathers together in New Yo...
# 9043    5/21/1982  Juliet Forrest is convinced that the reported ...
# 9044   11/10/1989  A novelist's wife and son see him changed by a...
# 9045    10/6/1979  A strong-willed peasant girl is sent by her fa...
# 9046    8/14/2014  The film tells the story of documentary filmma...
#
# [9047 rows x 9 columns]

# %%
import pandas as pd

# Assuming 'big_df' is your DataFrame
# Replace 'big_df' with your actual DataFrame

# Count the number of rows with one or more NaN values
num_rows_with_nan = big_df.isna().any(axis=1).sum()

print(f"Number of rows with one or more NaN values: {num_rows_with_nan}")
# Out:
# Number of rows with one or more NaN values: 304

# %%
import pandas as pd

# Assuming 'big_df' is your DataFrame
# Replace 'big_df' with your actual DataFrame

# Drop rows with one or more missing values
big_df.dropna(inplace=True)

# %%
big_df
# Out:
#                                               Title    Year  \
# 0                                           Kantara    2022
# 1                                   The Dark Knight    2008
# 2     The Lord of the Rings: The Return of the King    2003
# 3                                         Inception    2010
# 4             The Lord of the Rings: The Two Towers    2002
# ...                                             ...     ...
# 9041                              Love & Basketball  2000.0
# 9043                      Dead Men Don't Wear Plaid  1982.0
# 9044                                      Communion  1989.0
# 9045                                           Tess  1979.0
# 9046                 The Possession of Michael King  2014.0
#
#                    Director  \
# 0             Rishab Shetty
# 1         Christopher Nolan
# 2             Peter Jackson
# 3         Christopher Nolan
# 4             Peter Jackson
# ...                     ...
# 9041  Gina Prince-Bythewood
# 9043            Carl Reiner
# 9044          Philippe Mora
# 9045         Roman Polanski
# 9046             David Jung
#
#                                                  Actors  Rating Runtime  \
# 0     Rishab Shetty, Sapthami Gowda, Kishore Kumar G...     9.3     148
# 1     Christian Bale, Heath Ledger, Aaron Eckhart, M...     9.0     152
# 2     Elijah Wood, Viggo Mortensen, Ian McKellen, Or...     9.0     201
# 3     Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...     8.8     148
# 4     Elijah Wood, Ian McKellen, Viggo Mortensen, Or...     8.8     179
# ...                                                 ...     ...     ...
# 9041          Sanaa Lathan, Omar Epps, Glenndon Chatman     7.5     124
# 9043               Steve Martin, Rachel Ward, Alan Ladd     6.6      89
# 9044  Christopher Walken, Lindsay Crouse, Frances St...     5.3     103
# 9045        Nastassja Kinski, Peter Firth, Leigh Lawson     7.0     186
# 9046           Shane Johnson, Ella Anderson, Cara Pifko     6.1      83
#
#                                                   Genre Release_Date  \
# 0                                                Action    30-Sep-22
# 1                                                Action    18-Jul-08
# 2                                                Action    17-Dec-03
# 3                                                Action    16-Jul-10
# 4                                                Action    18-Dec-02
# ...                                                 ...          ...
# 9041                     ['Comedy', 'Drama', 'Romance']    4/21/2000
# 9043                              ['Comedy', 'Mystery']    5/21/1982
# 9044  ['Drama', 'Horror', 'Science Fiction', 'Thrill...   11/10/1989
# 9045                               ['Drama', 'Romance']    10/6/1979
# 9046                                         ['Horror']    8/14/2014
#
#                                            Plot_Summary
# 0     When greed paves the way for betrayal, schemin...
# 1     When the menace known as the Joker wreaks havo...
# 2     Gandalf and Aragorn lead the World of Men agai...
# 3     A thief who steals corporate secrets through t...
# 4     While Frodo and Sam edge closer to Mordor with...
# ...                                                 ...
# 9041  Monica Wright and Quincy McCall grew up in the...
# 9043  Juliet Forrest is convinced that the reported ...
# 9044  A novelist's wife and son see him changed by a...
# 9045  A strong-willed peasant girl is sent by her fa...
# 9046  The film tells the story of documentary filmma...
#
# [8743 rows x 9 columns]

# %%
import pandas as pd

# Assuming 'big_df' is your DataFrame
# Replace 'big_df' with your actual DataFrame

# Convert the 'Year' column to numeric, treating non-numeric values as NaN
big_df['Year'] = pd.to_numeric(big_df['Year'], errors='coerce')

# Convert the numeric values to integers, ignoring NaN values
big_df['Year'] = big_df['Year'].fillna(0).astype(int)

# %%
missing_values_count = big_df['Year'].isna().sum()

print(f"Number of missing values in the 'Release_Date' column: {missing_values_count}")
# Out:
# Number of missing values in the 'Release_Date' column: 0

# %%
import pandas as pd

# Assuming 'big_df' is your DataFrame
# Replace 'big_df' with your actual DataFrame

# Create three empty DataFrames for the three parts
big_df1 = pd.DataFrame(columns=big_df.columns)
big_df2 = pd.DataFrame(columns=big_df.columns)
big_df3 = pd.DataFrame(columns=big_df.columns)

# Function to split rows based on date format
def split_by_date_format(row):
    release_date = row['Release_Date']
    if pd.notna(release_date):
        try:
            # Attempt to parse the date with the format "dd-mmm-yy"
            parsed_date1 = pd.to_datetime(release_date, format='%d-%b-%y', errors='raise')
            # If parsing succeeds, it's in the specified format
            big_df1.loc[len(big_df1)] = row
        except ValueError:
            try:
                # Attempt to parse the date with the format "m/dd/yyyy"
                parsed_date2 = pd.to_datetime(release_date, format='%m/%d/%Y', errors='raise')
                # If parsing succeeds, it's in the specified format
                big_df2.loc[len(big_df2)] = row
            except ValueError:
                # If parsing fails for both formats, assume it's in 'dd mmm yyyy' format
                big_df3.loc[len(big_df3)] = row

# Apply the function to split rows based on date format
big_df.apply(split_by_date_format, axis=1)

# Reset the index of the resulting DataFrames if needed
big_df1.reset_index(drop=True, inplace=True)
big_df2.reset_index(drop=True, inplace=True)
big_df3.reset_index(drop=True, inplace=True)

# %%
#The dataset called bug_df is divided into three parts- big_df1, big_df2 and big_df3

# %%
import pandas as pd

# Assuming 'big_df2' is your DataFrame
# Replace 'big_df2' with your actual DataFrame

# Convert 'Year' column to a four-digit year format
big_df2['Year'] = big_df2['Year'].apply(lambda x: '20' + str(x) if len(str(x)) == 2 else str(x))

# Function to parse the 'Release_Date' column and standardize the date
def parse_and_standardize_date(row):
    release_date = row['Release_Date']
    year = row['Year']
    if pd.notna(release_date):
        date_parts = release_date.split(' ')
        if len(date_parts) == 3:
            day, month, year = date_parts
            month = month[:3]  # Extract the first three letters of the month
            standardized_date = f"{year}-{month}-{day}"
            return pd.to_datetime(standardized_date, format='%Y-%b-%d', errors='coerce')
    return pd.NaT

# Apply the function to create the 'Standardized_Date' column
big_df2['Release_Date'] = big_df2.apply(parse_and_standardize_date, axis=1)

# Drop the intermediate columns if not needed
#big_df2.drop(['Year'], axis=1, inplace=True)

# %%
big_df2
# Out:
#                                     Title  Year  \
# 0                                 No Exit  2022
# 1                            The Commando  2022
# 2                    Fistful of Vengeance  2022
# 3                                 Pursuit  2022
# 4     The Ice Age Adventures of Buck Wild  2022
# ...                                   ...   ...
# 3713                    Love & Basketball  2000
# 3714            Dead Men Don't Wear Plaid  1982
# 3715                            Communion  1989
# 3716                                 Tess  1979
# 3717       The Possession of Michael King  2014
#
#                                    Director  \
# 0                              Damien Power
# 1                                Asif Akbar
# 2                                Roel Reiné
# 3                               Brian Skiba
# 4     Marshall Fels Elliott, John C. Donkin
# ...                                     ...
# 3713                  Gina Prince-Bythewood
# 3714                            Carl Reiner
# 3715                          Philippe Mora
# 3716                         Roman Polanski
# 3717                             David Jung
#
#                                                  Actors Rating Runtime  \
# 0         Havana Rose Liu, Danny Ramirez, David Rysdahl    6.3  95 min
# 1          Mickey Rourke, Jeff Fahey, Michael Jai White    6.6  93 min
# 2                    Iko Uwais, Lewis Tan, Lawrence Kao    5.3  96 min
# 3     Emile Hirsch, Jake Manley, Elizabeth Faith Ludlow    5.9  95 min
# 4              Utkarsh Ambudkar, Sean Kenin, Jake Green    7.1  82 min
# ...                                                 ...    ...     ...
# 3713          Sanaa Lathan, Omar Epps, Glenndon Chatman    7.5     124
# 3714               Steve Martin, Rachel Ward, Alan Ladd    6.6      89
# 3715  Christopher Walken, Lindsay Crouse, Frances St...    5.3     103
# 3716        Nastassja Kinski, Peter Firth, Leigh Lawson    7.0     186
# 3717           Shane Johnson, Ella Anderson, Cara Pifko    6.1      83
#
#                                                   Genre Release_Date  \
# 0                                              Thriller  25 Feb 2022
# 1                               Action, Crime, Thriller  10 Jan 2022
# 2                                Action, Crime, Fantasy  17 Feb 2022
# 3                               Action, Crime, Thriller  18 Feb 2022
# 4                  Animation, Comedy, Adventure, Family  28 Jan 2022
# ...                                                 ...          ...
# 3713                     ['Comedy', 'Drama', 'Romance']    4/21/2000
# 3714                              ['Comedy', 'Mystery']    5/21/1982
# 3715  ['Drama', 'Horror', 'Science Fiction', 'Thrill...   11/10/1989
# 3716                               ['Drama', 'Romance']    10/6/1979
# 3717                                         ['Horror']    8/14/2014
#
#                                            Plot_Summary
# 0     During a blizzard and stranded at an isolated ...
# 1     A DEA agent returns home with PTSD after a bot...
# 2     Kai Jin, a young Chinatown chef in present day...
# 3     Detective Breslin crosses paths with Calloway,...
# 4     The Ice Age Adventures of Buck Wild continues ...
# ...                                                 ...
# 3713  Monica Wright and Quincy McCall grew up in the...
# 3714  Juliet Forrest is convinced that the reported ...
# 3715  A novelist's wife and son see him changed by a...
# 3716  A strong-willed peasant girl is sent by her fa...
# 3717  The film tells the story of documentary filmma...
#
# [3718 rows x 9 columns]

# %%
missing_values_count = big_df2['Release_Date'].isna().sum()

print(f"Number of missing values in the 'Release_Date' column: {missing_values_count}")
# Out:
# Number of missing values in the 'Release_Date' column: 1711

# %%
import pandas as pd

# Assuming 'big_df1' is your DataFrame
# Replace 'big_df1' with your actual DataFrame

# Convert 'Year' column to a four-digit year format
big_df1['Year'] = big_df1['Year'].apply(lambda x: '20' + str(x) if len(str(x)) == 2 else str(x))

# Function to parse the 'Release_Date' column and standardize the date
def parse_and_standardize_date(row):
    release_date = row['Release_Date']
    year = row['Year']
    if pd.notna(release_date):
        date_parts = release_date.split('-')
        if len(date_parts) == 3:
            day, month = date_parts[:2]
            standardized_date = f"{year}-{month}-{day}"
            return pd.to_datetime(standardized_date, format='%Y-%b-%d', errors='coerce')
    return pd.NaT

# Apply the function to create the 'Standardized_Date' column
big_df1['Release_Date'] = big_df1.apply(parse_and_standardize_date, axis=1)

# Drop the intermediate columns if not needed
#big_df1.drop(['Year'], axis=1, inplace=True)

# %%
big_df1
# Out:
#                                               Title  Year  \
# 0                                           Kantara  2022
# 1                                   The Dark Knight  2008
# 2     The Lord of the Rings: The Return of the King  2003
# 3                                         Inception  2010
# 4             The Lord of the Rings: The Two Towers  2002
# ...                                             ...   ...
# 5020                                 Disaster Movie  2008
# 5021                        The Hottie & the Nottie  2008
# 5022                           From Justin to Kelly  2003
# 5023                   Superbabies: Baby Geniuses 2  2004
# 5024                 Cumali Ceber: Allah Seni Alsin  2017
#
#                                       Director  \
# 0                                Rishab Shetty
# 1                            Christopher Nolan
# 2                                Peter Jackson
# 3                            Christopher Nolan
# 4                                Peter Jackson
# ...                                        ...
# 5020  Directors:Jason Friedberg, Aaron Seltzer
# 5021                                Tom Putnam
# 5022                             Robert Iscove
# 5023                                 Bob Clark
# 5024                                Gökhan Gök
#
#                                                  Actors Rating Runtime  \
# 0     Rishab Shetty, Sapthami Gowda, Kishore Kumar G...    9.3     148
# 1     Christian Bale, Heath Ledger, Aaron Eckhart, M...    9.0     152
# 2     Elijah Wood, Viggo Mortensen, Ian McKellen, Or...    9.0     201
# 3     Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...    8.8     148
# 4     Elijah Wood, Ian McKellen, Viggo Mortensen, Or...    8.8     179
# ...                                                 ...    ...     ...
# 5020  Carmen Electra, Vanessa Lachey, Nicole Parker,...    1.9      87
# 5021  Paris Hilton, Joel David Moore, Christine Laki...    1.9      91
# 5022  Kelly Clarkson, Justin Guarini, Katherine Bail...    1.9      81
# 5023  Jon Voight, Scott Baio, Vanessa Angel, Skyler ...    1.5      88
# 5024  Halil Söyletmez, Doga Konakoglu, Emre Keskin, ...    1.0     100
#
#        Genre Release_Date                                       Plot_Summary
# 0     Action   2022-09-30  When greed paves the way for betrayal, schemin...
# 1     Action   2008-07-18  When the menace known as the Joker wreaks havo...
# 2     Action   2003-12-17  Gandalf and Aragorn lead the World of Men agai...
# 3     Action   2010-07-16  A thief who steals corporate secrets through t...
# 4     Action   2002-12-18  While Frodo and Sam edge closer to Mordor with...
# ...      ...          ...                                                ...
# 5020  Comedy   2008-08-29  Over the course of one evening, an unsuspectin...
# 5021  Comedy   2008-02-21  A woman agrees to go on a date with a man only...
# 5022  Comedy   2003-06-20  A waitress from Texas and a college student fr...
# 5023  Comedy   2004-08-27  A group of smart-talking toddlers find themsel...
# 5024  Comedy   2017-08-04  Cumali Ceber goes to a vacation with his child...
#
# [5025 rows x 9 columns]

# %%
import pandas as pd

# Assuming 'big_df1' is your DataFrame
# Replace 'big_df1' with your actual DataFrame

# Convert 'Year' column to a four-digit year format
big_df1['Year'] = big_df1['Year'].apply(lambda x: '20' + str(x) if len(str(x)) == 2 else str(x))

# Function to parse the 'Release_Date' column and standardize the date
def parse_and_standardize_date(row):
    release_date = row['Release_Date']
    year = row['Year']
    if pd.notna(release_date):
        date_parts = release_date.split('-')
        if len(date_parts) == 3:
            day, month = date_parts[:2]
            standardized_date = f"{year}-{month}-{day}"
            return pd.to_datetime(standardized_date, format='%Y-%b-%d', errors='coerce')
    return pd.NaT

# Apply the function to create the 'Standardized_Date' column
big_df1['Release_Date'] = big_df1.apply(parse_and_standardize_date, axis=1)

# Drop the intermediate columns if not needed
#big_df1.drop(['Year'], axis=1, inplace=True)

# %%
# Out:
# Number of missing values in the 'Release_Date' column: 1

# %%
import pandas as pd

# Assuming 'big_df3' is your DataFrame
# Replace 'big_df3' with your actual DataFrame

# Convert 'Year' column to a four-digit year format
big_df3['Year'] = big_df3['Year'].apply(lambda x: '20' + str(x) if len(str(x)) == 2 else str(x))

# Function to parse the 'Release_Date' column and standardize the date
def parse_and_standardize_date(row):
    release_date = row['Release_Date']
    year = row['Year']
    if pd.notna(release_date):
        date_parts = release_date.split(' ')
        if len(date_parts) == 3:
            day, month, year = date_parts
            month = month[:3]  # Extract the first three letters of the month
            standardized_date = f"{year}-{month}-{day}"
            return pd.to_datetime(standardized_date, format='%Y-%b-%d', errors='coerce')
    return pd.NaT

# Apply the function to create the 'Standardized_Date' column
big_df3['Release_Date'] = big_df3.apply(parse_and_standardize_date, axis=1)

# Drop the intermediate columns if not needed
#big_df3.drop(['Year'], axis=1, inplace=True)

# %%
big_df3
# Out:
#                                                Title  Year  \
# 0                                            No Exit  2022
# 1                                       The Commando  2022
# 2                               Fistful of Vengeance  2022
# 3                                            Pursuit  2022
# 4                The Ice Age Adventures of Buck Wild  2022
# ...                                              ...   ...
# 2002                              Beyond White Space  2018
# 2003                                           Havoc  2005
# 2004           Batman: Return of the Caped Crusaders  2016
# 2005  One Crazy Summer: A Look Back at Gravity Falls  2018
# 2006                     Gunfight at the O.K. Corral  1957
#
#                                    Director  \
# 0                              Damien Power
# 1                                Asif Akbar
# 2                                Roel Reiné
# 3                               Brian Skiba
# 4     Marshall Fels Elliott, John C. Donkin
# ...                                     ...
# 2002                          Ken Locsmandi
# 2003                         Barbara Kopple
# 2004                           Rick Morales
# 2005                             Brian Ward
# 2006                           John Sturges
#
#                                                  Actors Rating  Runtime  \
# 0         Havana Rose Liu, Danny Ramirez, David Rysdahl    6.3   95 min
# 1          Mickey Rourke, Jeff Fahey, Michael Jai White    6.6   93 min
# 2                    Iko Uwais, Lewis Tan, Lawrence Kao    5.3   96 min
# 3     Emile Hirsch, Jake Manley, Elizabeth Faith Ludlow    5.9   95 min
# 4              Utkarsh Ambudkar, Sean Kenin, Jake Green    7.1   82 min
# ...                                                 ...    ...      ...
# 2002         Holt McCallany, Zulay Henao, Dave Sheridan    4.7   93 min
# 2003       Anne Hathaway, Bijou Phillips, Shiri Appleby    5.2   85 min
# 2004                 Adam West, Burt Ward, Julie Newmar    6.5   78 min
# 2005  Matt Braly, Brad Breeck, Jackie Buscarino, Rob...    2.0  105 min
# 2006       Burt Lancaster, Kirk Douglas, Rhonda Fleming    7.0  122 min
#
#                                                   Genre Release_Date  \
# 0                                              Thriller   2022-02-25
# 1                               Action, Crime, Thriller   2022-01-10
# 2                                Action, Crime, Fantasy   2022-02-17
# 3                               Action, Crime, Thriller   2022-02-18
# 4                  Animation, Comedy, Adventure, Family   2022-01-28
# ...                                                 ...          ...
# 2002                          Science Fiction, Thriller   2018-12-14
# 2003                                       Crime, Drama   2005-10-16
# 2004  Action, Animation, Adventure, Crime, Science F...   2016-10-11
# 2005                                        Documentary   2018-07-24
# 2006                                            Western   1957-05-30
#
#                                            Plot_Summary
# 0     During a blizzard and stranded at an isolated ...
# 1     A DEA agent returns home with PTSD after a bot...
# 2     Kai Jin, a young Chinatown chef in present day...
# 3     Detective Breslin crosses paths with Calloway,...
# 4     The Ice Age Adventures of Buck Wild continues ...
# ...                                                 ...
# 2002  The USS Essex is travelling in the furthest re...
# 2003  Two affluent suburban girls clash with the Lat...
# 2004  Batman and Robin of the 1960s live action seri...
# 2005  The ultimate Gravity Falls behind the scenes d...
# 2006  Lawman Wyatt Earp and outlaw Doc Holliday form...
#
# [2007 rows x 9 columns]

# %%
# Combine the three DataFrames into 'new_big_df'
new_big_df = pd.concat([big_df1, big_df2, big_df3], ignore_index=True)

# Reset the index of the resulting DataFrame
new_big_df.reset_index(drop=True, inplace=True)

# %%
new_big_df
# Out:
#                                                Title  Year           Director  \
# 0                                            Kantara  2022      Rishab Shetty
# 1                                    The Dark Knight  2008  Christopher Nolan
# 2      The Lord of the Rings: The Return of the King  2003      Peter Jackson
# 3                                          Inception  2010  Christopher Nolan
# 4              The Lord of the Rings: The Two Towers  2002      Peter Jackson
# ...                                              ...   ...                ...
# 8738                              Beyond White Space  2018      Ken Locsmandi
# 8739                                           Havoc  2005     Barbara Kopple
# 8740           Batman: Return of the Caped Crusaders  2016       Rick Morales
# 8741  One Crazy Summer: A Look Back at Gravity Falls  2018         Brian Ward
# 8742                     Gunfight at the O.K. Corral  1957       John Sturges
#
#                                                  Actors Rating  Runtime  \
# 0     Rishab Shetty, Sapthami Gowda, Kishore Kumar G...    9.3      148
# 1     Christian Bale, Heath Ledger, Aaron Eckhart, M...    9.0      152
# 2     Elijah Wood, Viggo Mortensen, Ian McKellen, Or...    9.0      201
# 3     Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...    8.8      148
# 4     Elijah Wood, Ian McKellen, Viggo Mortensen, Or...    8.8      179
# ...                                                 ...    ...      ...
# 8738         Holt McCallany, Zulay Henao, Dave Sheridan    4.7   93 min
# 8739       Anne Hathaway, Bijou Phillips, Shiri Appleby    5.2   85 min
# 8740                 Adam West, Burt Ward, Julie Newmar    6.5   78 min
# 8741  Matt Braly, Brad Breeck, Jackie Buscarino, Rob...    2.0  105 min
# 8742       Burt Lancaster, Kirk Douglas, Rhonda Fleming    7.0  122 min
#
#                                                   Genre         Release_Date  \
# 0                                                Action  2022-09-30 00:00:00
# 1                                                Action  2008-07-18 00:00:00
# 2                                                Action  2003-12-17 00:00:00
# 3                                                Action  2010-07-16 00:00:00
# 4                                                Action  2002-12-18 00:00:00
# ...                                                 ...                  ...
# 8738                          Science Fiction, Thriller  2018-12-14 00:00:00
# 8739                                       Crime, Drama  2005-10-16 00:00:00
# 8740  Action, Animation, Adventure, Crime, Science F...  2016-10-11 00:00:00
# 8741                                        Documentary  2018-07-24 00:00:00
# 8742                                            Western  1957-05-30 00:00:00
#
#                                            Plot_Summary
# 0     When greed paves the way for betrayal, schemin...
# 1     When the menace known as the Joker wreaks havo...
# 2     Gandalf and Aragorn lead the World of Men agai...
# 3     A thief who steals corporate secrets through t...
# 4     While Frodo and Sam edge closer to Mordor with...
# ...                                                 ...
# 8738  The USS Essex is travelling in the furthest re...
# 8739  Two affluent suburban girls clash with the Lat...
# 8740  Batman and Robin of the 1960s live action seri...
# 8741  The ultimate Gravity Falls behind the scenes d...
# 8742  Lawman Wyatt Earp and outlaw Doc Holliday form...
#
# [8743 rows x 9 columns]

# %%
combined_all = pd.concat([new_big_df, combined_df2, new_comb], axis=0, ignore_index=True)
combined_all
# Out:
#                                                Title  Year  \
# 0                                            Kantara  2022
# 1                                    The Dark Knight  2008
# 2      The Lord of the Rings: The Return of the King  2003
# 3                                          Inception  2010
# 4              The Lord of the Rings: The Two Towers  2002
# ...                                              ...   ...
# 20081                                 Disaster Movie  2008
# 20082                        The Hottie & the Nottie  2008
# 20083                           From Justin to Kelly  2003
# 20084                   Superbabies: Baby Geniuses 2  2004
# 20085                 Cumali Ceber: Allah Seni Alsin  2017
#
#                                        Director  \
# 0                                 Rishab Shetty
# 1                             Christopher Nolan
# 2                                 Peter Jackson
# 3                             Christopher Nolan
# 4                                 Peter Jackson
# ...                                         ...
# 20081  Directors:Jason Friedberg, Aaron Seltzer
# 20082                                Tom Putnam
# 20083                             Robert Iscove
# 20084                                 Bob Clark
# 20085                                Gökhan Gök
#
#                                                   Actors Rating Runtime  \
# 0      Rishab Shetty, Sapthami Gowda, Kishore Kumar G...    9.3     148
# 1      Christian Bale, Heath Ledger, Aaron Eckhart, M...    9.0     152
# 2      Elijah Wood, Viggo Mortensen, Ian McKellen, Or...    9.0     201
# 3      Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...    8.8     148
# 4      Elijah Wood, Ian McKellen, Viggo Mortensen, Or...    8.8     179
# ...                                                  ...    ...     ...
# 20081  Carmen Electra, Vanessa Lachey, Nicole Parker,...    1.9      87
# 20082  Paris Hilton, Joel David Moore, Christine Laki...    1.9      91
# 20083  Kelly Clarkson, Justin Guarini, Katherine Bail...    1.9      81
# 20084  Jon Voight, Scott Baio, Vanessa Angel, Skyler ...    1.5      88
# 20085  Halil Söyletmez, Doga Konakoglu, Emre Keskin, ...    1.0     100
#
#         Genre         Release_Date  \
# 0      Action  2022-09-30 00:00:00
# 1      Action  2008-07-18 00:00:00
# 2      Action  2003-12-17 00:00:00
# 3      Action  2010-07-16 00:00:00
# 4      Action  2002-12-18 00:00:00
# ...       ...                  ...
# 20081  Comedy  2008-08-29 00:00:00
# 20082  Comedy  2008-02-21 00:00:00
# 20083  Comedy  2003-06-20 00:00:00
# 20084  Comedy  2004-08-27 00:00:00
# 20085  Comedy  2017-08-04 00:00:00
#
#                                             Plot_Summary
# 0      When greed paves the way for betrayal, schemin...
# 1      When the menace known as the Joker wreaks havo...
# 2      Gandalf and Aragorn lead the World of Men agai...
# 3      A thief who steals corporate secrets through t...
# 4      While Frodo and Sam edge closer to Mordor with...
# ...                                                  ...
# 20081  Over the course of one evening, an unsuspectin...
# 20082  A woman agrees to go on a date with a man only...
# 20083  A waitress from Texas and a college student fr...
# 20084  A group of smart-talking toddlers find themsel...
# 20085  Cumali Ceber goes to a vacation with his child...
#
# [20086 rows x 9 columns]

# %%
# Remove duplicates from the combined_all DataFrame
combined_all = combined_all.drop_duplicates()

# Reset the index of the resulting DataFrame
combined_all.reset_index(drop=True, inplace=True)

# %%
combined_all
# Out:
#                                                Title  Year  \
# 0                                            Kantara  2022
# 1                                    The Dark Knight  2008
# 2      The Lord of the Rings: The Return of the King  2003
# 3                                          Inception  2010
# 4              The Lord of the Rings: The Two Towers  2002
# ...                                              ...   ...
# 17274                                 Disaster Movie  2008
# 17275                        The Hottie & the Nottie  2008
# 17276                           From Justin to Kelly  2003
# 17277                   Superbabies: Baby Geniuses 2  2004
# 17278                 Cumali Ceber: Allah Seni Alsin  2017
#
#                                        Director  \
# 0                                 Rishab Shetty
# 1                             Christopher Nolan
# 2                                 Peter Jackson
# 3                             Christopher Nolan
# 4                                 Peter Jackson
# ...                                         ...
# 17274  Directors:Jason Friedberg, Aaron Seltzer
# 17275                                Tom Putnam
# 17276                             Robert Iscove
# 17277                                 Bob Clark
# 17278                                Gökhan Gök
#
#                                                   Actors Rating Runtime  \
# 0      Rishab Shetty, Sapthami Gowda, Kishore Kumar G...    9.3     148
# 1      Christian Bale, Heath Ledger, Aaron Eckhart, M...    9.0     152
# 2      Elijah Wood, Viggo Mortensen, Ian McKellen, Or...    9.0     201
# 3      Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...    8.8     148
# 4      Elijah Wood, Ian McKellen, Viggo Mortensen, Or...    8.8     179
# ...                                                  ...    ...     ...
# 17274  Carmen Electra, Vanessa Lachey, Nicole Parker,...    1.9      87
# 17275  Paris Hilton, Joel David Moore, Christine Laki...    1.9      91
# 17276  Kelly Clarkson, Justin Guarini, Katherine Bail...    1.9      81
# 17277  Jon Voight, Scott Baio, Vanessa Angel, Skyler ...    1.5      88
# 17278  Halil Söyletmez, Doga Konakoglu, Emre Keskin, ...    1.0     100
#
#         Genre         Release_Date  \
# 0      Action  2022-09-30 00:00:00
# 1      Action  2008-07-18 00:00:00
# 2      Action  2003-12-17 00:00:00
# 3      Action  2010-07-16 00:00:00
# 4      Action  2002-12-18 00:00:00
# ...       ...                  ...
# 17274  Comedy  2008-08-29 00:00:00
# 17275  Comedy  2008-02-21 00:00:00
# 17276  Comedy  2003-06-20 00:00:00
# 17277  Comedy  2004-08-27 00:00:00
# 17278  Comedy  2017-08-04 00:00:00
#
#                                             Plot_Summary
# 0      When greed paves the way for betrayal, schemin...
# 1      When the menace known as the Joker wreaks havo...
# 2      Gandalf and Aragorn lead the World of Men agai...
# 3      A thief who steals corporate secrets through t...
# 4      While Frodo and Sam edge closer to Mordor with...
# ...                                                  ...
# 17274  Over the course of one evening, an unsuspectin...
# 17275  A woman agrees to go on a date with a man only...
# 17276  A waitress from Texas and a college student fr...
# 17277  A group of smart-talking toddlers find themsel...
# 17278  Cumali Ceber goes to a vacation with his child...
#
# [17279 rows x 9 columns]

# %%
# Count the number of duplicate movie titles in the 'Title' column
duplicate_titles = combined_all[combined_all['Title'].duplicated(keep=False)]
num_duplicate_titles = len(duplicate_titles)

print(f"Number of duplicate movie titles: {num_duplicate_titles}")
# Out:
# Number of duplicate movie titles: 13006

# %%
# Remove rows with the same value in the 'Title' column
combined_all = combined_all.drop_duplicates(subset=['Title'])

# Reset the index of the resulting DataFrame
combined_all.reset_index(drop=True, inplace=True)

# %%
combined_all
# Out:
#                                               Title  Year  \
# 0                                           Kantara  2022
# 1                                   The Dark Knight  2008
# 2     The Lord of the Rings: The Return of the King  2003
# 3                                         Inception  2010
# 4             The Lord of the Rings: The Two Towers  2002
# ...                                             ...   ...
# 9355             A Very Harold & Kumar 3D Christmas  2011
# 9356                  Astérix & Obélix contre César  1999
# 9357                    Astérix aux jeux olympiques  2008
# 9358                                Celal ile Ceren  2013
# 9359                 Enes Batur Hayal mi Gerçek mi?  2018
#
#                                            Director  \
# 0                                     Rishab Shetty
# 1                                 Christopher Nolan
# 2                                     Peter Jackson
# 3                                 Christopher Nolan
# 4                                     Peter Jackson
# ...                                             ...
# 9355                          Todd Strauss-Schulson
# 9356                                    Claude Zidi
# 9357  Directors:Frédéric Forestier, Thomas Langmann
# 9358                                 Togan Gökbakar
# 9359                                    Kamil Cetin
#
#                                                  Actors Rating Runtime  \
# 0     Rishab Shetty, Sapthami Gowda, Kishore Kumar G...    9.3     148
# 1     Christian Bale, Heath Ledger, Aaron Eckhart, M...    9.0     152
# 2     Elijah Wood, Viggo Mortensen, Ian McKellen, Or...    9.0     201
# 3     Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...    8.8     148
# 4     Elijah Wood, Ian McKellen, Viggo Mortensen, Or...    8.8     179
# ...                                                 ...    ...     ...
# 9355  Kal Penn, John Cho, Neil Patrick Harris, Patto...    6.2      90
# 9356  Christian Clavier, Gérard Depardieu, Roberto B...    5.9     109
# 9357  Gérard Depardieu, Clovis Cornillac, Benoît Poe...    5.2     116
# 9358  Sahan Gökbakar, Ezgi Mola, Dilsah Demir, Gokce...    3.0     114
# 9359  Enes Batur, Bilal Hanci, Atakan Özyurt, Fatih ...    2.0     110
#
#           Genre         Release_Date  \
# 0        Action  2022-09-30 00:00:00
# 1        Action  2008-07-18 00:00:00
# 2        Action  2003-12-17 00:00:00
# 3        Action  2010-07-16 00:00:00
# 4        Action  2002-12-18 00:00:00
# ...         ...                  ...
# 9355  Adventure                  NaT
# 9356  Adventure                  NaT
# 9357  Adventure                  NaT
# 9358     Comedy                  NaT
# 9359     Comedy                  NaT
#
#                                            Plot_Summary
# 0     When greed paves the way for betrayal, schemin...
# 1     When the menace known as the Joker wreaks havo...
# 2     Gandalf and Aragorn lead the World of Men agai...
# 3     A thief who steals corporate secrets through t...
# 4     While Frodo and Sam edge closer to Mordor with...
# ...                                                 ...
# 9355                                                NaN
# 9356                                                NaN
# 9357                                                NaN
# 9358                                                NaN
# 9359                                                NaN
#
# [9360 rows x 9 columns]

# %%
#dropping rows with no dates6
combined_all = combined_all.dropna(subset=['Release_Date'])

# Reset the index of the resulting DataFrame
combined_all.reset_index(drop=True, inplace=True)

# %%
combined_all
# Out:
#                                                 Title  Year  \
# 0                                             Kantara  2022
# 1                                     The Dark Knight  2008
# 2       The Lord of the Rings: The Return of the King  2003
# 3                                           Inception  2010
# 4               The Lord of the Rings: The Two Towers  2002
# ...                                               ...   ...
# 8836                                        Idioterne  1998
# 8837  To Wong Foo Thanks for Everything, Julie Newmar  1995
# 8838                                          Oxygène  2021
# 8839                                            Hausu  1977
# 8840              Astérix & Obélix: Mission Cléopâtre  2002
#
#                Director                                             Actors  \
# 0         Rishab Shetty  Rishab Shetty, Sapthami Gowda, Kishore Kumar G...
# 1     Christopher Nolan  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 2         Peter Jackson  Elijah Wood, Viggo Mortensen, Ian McKellen, Or...
# 3     Christopher Nolan  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 4         Peter Jackson  Elijah Wood, Ian McKellen, Viggo Mortensen, Or...
# ...                 ...                                                ...
# 8836     Lars von Trier  Bodil Jørgensen, Jens Albinus, Anne Louise Has...
# 8837      Beeban Kidron  Wesley Snipes, Patrick Swayze, John Leguizamo,...
# 8838      Alexandre Aja  Mélanie Laurent, Mathieu Amalric, Malik Zidi, ...
# 8839  Nobuhiko Ôbayashi  Kimiko Ikegami, Miki Jinbo, Kumiko Ôba, Ai Mat...
# 8840       Alain Chabat  Gérard Depardieu, Christian Clavier, Jamel Deb...
#
#      Rating Runtime      Genre         Release_Date  \
# 0       9.3     148     Action  2022-09-30 00:00:00
# 1       9.0     152     Action  2008-07-18 00:00:00
# 2       9.0     201     Action  2003-12-17 00:00:00
# 3       8.8     148     Action  2010-07-16 00:00:00
# 4       8.8     179     Action  2002-12-18 00:00:00
# ...     ...     ...        ...                  ...
# 8836    6.8     117     Comedy  1998-10-12 00:00:00
# 8837    6.6     109     Comedy  1995-09-01 00:00:00
# 8838    6.5     100      Drama  2021-11-18 00:00:00
# 8839    7.3      88     Comedy  1977-02-13 00:00:00
# 8840    6.6     107  Adventure  2002-08-28 00:00:00
#
#                                            Plot_Summary
# 0     When greed paves the way for betrayal, schemin...
# 1     When the menace known as the Joker wreaks havo...
# 2     Gandalf and Aragorn lead the World of Men agai...
# 3     A thief who steals corporate secrets through t...
# 4     While Frodo and Sam edge closer to Mordor with...
# ...                                                 ...
# 8836                                                NaN
# 8837                                                NaN
# 8838                                                NaN
# 8839                                                NaN
# 8840                                                NaN
#
# [8841 rows x 9 columns]
